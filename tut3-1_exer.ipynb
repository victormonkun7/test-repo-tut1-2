# %%
person = ('A', 24, 'eng')
person = name, age, job
print(name)
print(person[0])
# Out:
# A
# A

# %%
import urllib.request
import PIL.Image
import matplotlib.pyplot as plt
import PIL
import urllib

image_url = 'https://upload.wikimedia.org/wikipedia/commons/a/a4/2019_Toyota_Corolla_Icon_Tech_VVT-i_Hybrid_1.8.jpg'

image_data = urllib.request.urlopen(image_url)
image = PIL.Image.open(image_data)
np_image = np.array(image)

plt.imshow(np_image)

# %%
np_image.shape
# Out:
# (2592, 4925, 3)

# %%
plt.imshow(np_image[200:500, 100:500, 1:2])

# %%
image_red_only = np_image.copy()
image_red_only[200:500,:,0] = 0
image_red_only[200:500,:,2] = 0

plt.imshow(image_red_only)
